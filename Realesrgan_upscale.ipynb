# %%
import cv2
import glob
import os
import re
from basicsr.archs.rrdbnet_arch import RRDBNet
from basicsr.utils.download_util import load_file_from_url
from realesrgan import RealESRGANer
from realesrgan.archs.srvgg_arch import SRVGGNetCompact

def remove_korean(text):
    # 한글을 삭제한 파일 이름을 반환
    return re.sub(r'[가-힣]', '', text)

def temp_rename_files_remove_korean(input_folder):
    # 파일 이름에서 한글을 제거하고, 원래 이름과 매핑된 딕셔너리 반환
    file_map = {}
    for filename in os.listdir(input_folder):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            original_path = os.path.join(input_folder, filename)
            # 한글을 제거한 이름 생성
            english_name = remove_korean(filename)
            new_path = os.path.join(input_folder, english_name)
            
            os.rename(original_path, new_path)
            file_map[new_path] = original_path  # 변경된 이름과 원래 이름 매핑

    return file_map

def revert_filenames(file_map):
    # 변경된 이름을 원래 이름으로 복원
    for new_name, original_name in file_map.items():
        os.rename(new_name, original_name)

def enhance_images(input_path, output_path, model_name='RealESRGAN_x4plus', denoise_strength=0.5, outscale=4, 
                   model_path=None, suffix='out', tile=0, tile_pad=10, pre_pad=0, face_enhance=False, 
                   fp32=False, alpha_upsampler='realesrgan', ext='auto', gpu_id=None):
    
    # 한글을 제거한 임시 파일 이름으로 변경
    file_map = temp_rename_files_remove_korean(input_path)

    try:
        # 모델 선택에 따른 설정
        model_name = model_name.split('.')[0]
        if model_name == 'RealESRGAN_x4plus':  # x4 RRDBNet 모델
            model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4)
            netscale = 4
            file_url = ['https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth']
        elif model_name == 'RealESRNet_x4plus':  # x4 RRDBNet 모델
            model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4)
            netscale = 4
            file_url = ['https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.1/RealESRNet_x4plus.pth']
        elif model_name == 'RealESRGAN_x4plus_anime_6B':  # x4 RRDBNet 모델 (6블록)
            model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=6, num_grow_ch=32, scale=4)
            netscale = 4
            file_url = ['https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.4/RealESRGAN_x4plus_anime_6B.pth']
        elif model_name == 'RealESRGAN_x2plus':  # x2 RRDBNet 모델
            model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=2)
            netscale = 2
            file_url = ['https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.1/RealESRGAN_x2plus.pth']
        elif model_name == 'realesr-animevideov3':  # x4 VGG 스타일 모델 (XS 크기)
            model = SRVGGNetCompact(num_in_ch=3, num_out_ch=3, num_feat=64, num_conv=16, upscale=4, act_type='prelu')
            netscale = 4
            file_url = ['https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesr-animevideov3.pth']
        elif model_name == 'realesr-general-x4v3':  # x4 VGG 스타일 모델 (S 크기)
            model = SRVGGNetCompact(num_in_ch=3, num_out_ch=3, num_feat=64, num_conv=32, upscale=4, act_type='prelu')
            netscale = 4
            file_url = [
                'https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesr-general-wdn-x4v3.pth',
                'https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesr-general-x4v3.pth'
            ]

        # 모델 경로 결정
        if model_path is not None:
            model_path = model_path
        else:
            model_path = os.path.join('weights', model_name + '.pth')
            if not os.path.isfile(model_path):
                ROOT_DIR = os.path.dirname(os.path.abspath(''))
                for url in file_url:
                    model_path = load_file_from_url(
                        url=url, model_dir=os.path.join(ROOT_DIR, 'weights'), progress=True, file_name=None)

        # 노이즈 제거 강도를 제어하는 DNI 사용
        dni_weight = None
        if model_name == 'realesr-general-x4v3' and denoise_strength != 1:
            wdn_model_path = model_path.replace('realesr-general-x4v3', 'realesr-general-wdn-x4v3')
            model_path = [model_path, wdn_model_path]
            dni_weight = [denoise_strength, 1 - denoise_strength]

        # 복원기 설정
        upsampler = RealESRGANer(
            scale=netscale,
            model_path=model_path,
            dni_weight=dni_weight,
            model=model,
            tile=tile,
            tile_pad=tile_pad,
            pre_pad=pre_pad,
            half=not fp32,
            gpu_id=gpu_id)

        # 얼굴 향상을 위한 GFPGAN 사용 옵션
        if face_enhance:
            from gfpgan import GFPGANer
            face_enhancer = GFPGANer(
                model_path='https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth',
                upscale=outscale,
                arch='clean',
                channel_multiplier=2,
                bg_upsampler=upsampler)

        os.makedirs(output_path, exist_ok=True)

        # 입력 경로 처리
        if os.path.isfile(input_path):
            paths = [input_path]
        else:
            paths = sorted(glob.glob(os.path.join(input_path, '*')))

        # 이미지 처리
        for idx, path in enumerate(paths):
            imgname, extension = os.path.splitext(os.path.basename(path))
            print('Processing', idx, imgname)

            img = cv2.imread(os.path.abspath(path), cv2.IMREAD_UNCHANGED)
            
            if img is None:
                print(f"Error reading image {path}, skipping...")
                continue

            if len(img.shape) == 3 and img.shape[2] == 4:
                img_mode = 'RGBA'
            else:
                img_mode = None

            try:
                if face_enhance:
                    _, _, output = face_enhancer.enhance(img, has_aligned=False, only_center_face=False, paste_back=True)
                else:
                    output, _ = upsampler.enhance(img, outscale=outscale)
            except RuntimeError as error:
                print('Error:', error)
                print('If you encounter CUDA out of memory, try to set --tile with a smaller number.')
                continue

            # 확장자 처리
            if ext == 'auto':
                extension = extension[1:]
            else:
                extension = ext
            if img_mode == 'RGBA':  # RGBA 이미지들은 PNG 형식으로 저장되어야 함
                extension = 'png'
            if suffix == '':
                save_path = os.path.join(output_path, f'{imgname}.{extension}')
            else:
                save_path = os.path.join(output_path, f'{imgname}_{suffix}.{extension}')
            cv2.imwrite(save_path, output)
            print(f"Saved: {save_path}")
    finally:
        # 작업 후 파일 이름 복원
        revert_filenames(file_map)

# %%
enhance_images(
    input_path= os.path.abspath('data/img_labeling/dh/cropped_number_plate_gray/'),
    output_path= os.path.abspath('data/img_labeling/dh/cropped_number_plate_gray/up/'),
    model_name='RealESRGAN_x4plus_anime_6B',
    denoise_strength=1,
    outscale=4,
    model_path= None,
    suffix='out',
    tile=0,
    tile_pad=10,
    pre_pad=0,
    face_enhance=False,
    fp32=True,
    alpha_upsampler='realesrgan',
    ext='auto',
    gpu_id=None
)

# enhance_images(
#     input_path= os.path.abspath('data/img_labeling/dh/cropped_number_plate/upscaled1/'),
#     output_path= os.path.abspath('data/img_labeling/dh/cropped_number_plate/upscaled2/'),
#     model_name='RealESRGAN_x4plus_anime_6B',
#     denoise_strength=0.8,
#     outscale=4,
#     model_path= None,
#     suffix='out2',
#     tile=0,
#     tile_pad=10,
#     pre_pad=0,
#     face_enhance=False,
#     fp32=True,
#     alpha_upsampler='realesrgan',
#     ext='auto',
#     gpu_id=None
# )
# 설명: 입력 이미지 파일 또는 폴더의 경로를 지정합니다. 만약 폴더 경로를 지정하면 해당 폴더 내의 모든 이미지가 처리됩니다.
# 예시: 'inputs' (폴더 경로) 또는 'inputs/image.jpg' (파일 경로).
# output_path:

# 설명: 처리된 이미지를 저장할 출력 폴더의 경로를 지정합니다. 이 폴더는 존재하지 않으면 자동으로 생성됩니다.
# 예시: 'results'.
# model_name:

# 설명: 사용할 Real-ESRGAN 모델의 이름을 지정합니다. 아래의 모델 중 하나를 선택할 수 있습니다:
# 'RealESRGAN_x4plus': 일반적인 이미지 슈퍼 해상도를 위한 모델.
# 'RealESRNet_x4plus': 노이즈가 줄어든 버전의 모델.
# 'RealESRGAN_x4plus_anime_6B': 애니메이션 이미지에 특화된 모델.
# 'RealESRGAN_x2plus': 2배 슈퍼 해상도를 위한 모델.
# 'realesr-animevideov3': 애니메이션 비디오에 특화된 모델.
# 'realesr-general-x4v3': 다양한 이미지에 사용할 수 있는 범용 모델.
# 예시: 'RealESRGAN_x4plus'.
# denoise_strength:

# 설명: 노이즈 제거 강도를 설정합니다. 값이 0이면 약한 노이즈 제거, 1이면 강한 노이즈 제거를 의미합니다. 이 파라미터는 'realesr-general-x4v3' 모델에서만 사용됩니다.
# 예시: 0.5.
# outscale:

# 설명: 최종 업스케일 배율을 설정합니다. 예를 들어, 값이 4이면 이미지의 해상도가 4배로 증가합니다.
# 예시: 4.
# model_path:

# 설명: 사전 학습된 모델 파일의 경로를 지정합니다. 지정하지 않으면 코드가 자동으로 모델을 다운로드하여 사용합니다.
# 예시: None (자동 다운로드) 또는 'path/to/model.pth'.
# suffix:

# 설명: 출력 이미지 파일명에 추가될 접미사를 지정합니다. 예를 들어, 'out'으로 지정하면, 결과 파일명은 'image_out.png'가 됩니다.
# 예시: 'out'.
# tile:

# 설명: 타일 크기를 지정합니다. 타일링은 메모리 사용을 줄이기 위해 이미지의 일부를 나누어 처리하는 방법입니다. 값이 0이면 타일 없이 처리합니다.
# 예시: 0 (타일링 비활성화) 또는 512 (512x512 크기의 타일 사용).
# tile_pad:

# 설명: 타일 간의 겹침 영역(패딩)을 설정합니다. 타일링을 사용할 때 경계 부분의 연속성을 보장하기 위해 사용됩니다.
# 예시: 10.
# pre_pad:

# 설명: 이미지 처리 전 가장자리 패딩 크기를 설정합니다. 값이 0이면 패딩이 없습니다.
# 예시: 0.
# face_enhance:

# 설명: 얼굴 향상을 위해 GFPGAN 모델을 사용할지 여부를 설정합니다. 이 옵션이 활성화되면 얼굴 부분이 더 정밀하게 복원됩니다.
# 예시: False (비활성화) 또는 True (활성화).
# fp32:

# 설명: FP32(32-bit floating point) 정밀도를 사용할지 설정합니다. 기본값은 FP16(half precision)으로, 메모리 사용량을 줄이고 속도를 높일 수 있습니다.
# 예시: False (FP16 사용) 또는 True (FP32 사용).
# alpha_upsampler:

# 설명: 알파 채널(투명도 채널) 업샘플링에 사용할 방식을 지정합니다. 선택 가능한 옵션은 'realesrgan' 또는 'bicubic'입니다.
# 예시: 'realesrgan' (Real-ESRGAN 방식 사용) 또는 'bicubic' (Bi-cubic 방식 사용).
# ext:

# 설명: 출력 이미지의 파일 확장자를 지정합니다. 'auto'로 설정하면 입력 이미지와 동일한 확장자를 사용합니다.
# 예시: 'auto', 'jpg', 'png'.
# gpu_id:

# 설명: 사용할 GPU의 ID를 지정합니다. 다중 GPU 환경에서 특정 GPU를 선택할 수 있습니다. 기본값은 None으로, 이 경우 기본 GPU가 사용됩니다.
# 예시: 0 (첫 번째 GPU 사용), 1 (두 번째 GPU 사용) 또는 None (기본 설정 사용).
# Out:
# Processing 0 1193 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1193 (2)_crop_0_out1.jpg
# Processing 1 1193 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1193 (3)_crop_0_out1.jpg
# Processing 2 1193_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1193_crop_0_out1.jpg
# Processing 3 1211 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211 (2)_crop_0_out1.jpg
# Processing 4 1211 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211 (3)_crop_0_out1.jpg
# Processing 5 1211 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211 (4)_crop_0_out1.jpg
# Processing 6 1211 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211 (5)_crop_0_out1.jpg
# Processing 7 1211 (5)_crop_1
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211 (5)_crop_1_out1.jpg
# Processing 8 1211_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1211_crop_0_out1.jpg
# Processing 9 1221 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1221 (1)_crop_0_out1.jpg
# Processing 10 1221 (1)_crop_1
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1221 (1)_crop_1_out1.jpg
# Processing 11 1221 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1221 (2)_crop_0_out1.jpg
# Processing 12 1221_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1221_crop_0_out1.jpg
# Processing 13 1296 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296 (2)_crop_0_out1.jpg
# Processing 14 1296 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296 (3)_crop_0_out1.jpg
# Processing 15 1296 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296 (4)_crop_0_out1.jpg
# Processing 16 1296 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296 (5)_crop_0_out1.jpg
# Processing 17 1296 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296 (6)_crop_0_out1.jpg
# Processing 18 1296_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1296_crop_0_out1.jpg
# Processing 19 1379 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (10)_crop_0_out1.jpg
# Processing 20 1379 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (11)_crop_0_out1.jpg
# Processing 21 1379 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (12)_crop_0_out1.jpg
# Processing 22 1379 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (13)_crop_0_out1.jpg
# Processing 23 1379 (14)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (14)_crop_0_out1.jpg
# Processing 24 1379 (15)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (15)_crop_0_out1.jpg
# Processing 25 1379 (16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (16)_crop_0_out1.jpg
# Processing 26 1379 (17)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (17)_crop_0_out1.jpg
# Processing 27 1379 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (2)_crop_0_out1.jpg
# Processing 28 1379 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (3)_crop_0_out1.jpg
# Processing 29 1379 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (4)_crop_0_out1.jpg
# Processing 30 1379 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (5)_crop_0_out1.jpg
# Processing 31 1379 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (6)_crop_0_out1.jpg
# Processing 32 1379 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (7)_crop_0_out1.jpg
# Processing 33 1379 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (8)_crop_0_out1.jpg
# Processing 34 1379 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379 (9)_crop_0_out1.jpg
# Processing 35 1379_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1379_crop_0_out1.jpg
# Processing 36 1459 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (1)_crop_0_out1.jpg
# Processing 37 1459 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (10)_crop_0_out1.jpg
# Processing 38 1459 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (11)_crop_0_out1.jpg
# Processing 39 1459 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (12)_crop_0_out1.jpg
# Processing 40 1459 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (13)_crop_0_out1.jpg
# Processing 41 1459 (14)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (14)_crop_0_out1.jpg
# Processing 42 1459 (15)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (15)_crop_0_out1.jpg
# Processing 43 1459 (16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (16)_crop_0_out1.jpg
# Processing 44 1459 (17)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (17)_crop_0_out1.jpg
# Processing 45 1459 (18)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 (18)_crop_0_out1.jpg
# Processing 46 1459 (19)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\1459 
(16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (16)_crop_0_out1.jpg
# Processing 266 2466 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (2)_crop_0_out1.jpg
# Processing 267 2466 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (3)_crop_0_out1.jpg
# Processing 268 2466 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (4)_crop_0_out1.jpg
# Processing 269 2466 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (5)_crop_0_out1.jpg
# Processing 270 2466 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (6)_crop_0_out1.jpg
# Processing 271 2466 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (7)_crop_0_out1.jpg
# Processing 272 2466 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (8)_crop_0_out1.jpg
# Processing 273 2466 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466 (9)_crop_0_out1.jpg
# Processing 274 2466_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2466_crop_0_out1.jpg
# Processing 275 2559 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (10)_crop_0_out1.jpg
# Processing 276 2559 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (11)_crop_0_out1.jpg
# Processing 277 2559 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (12)_crop_0_out1.jpg
# Processing 278 2559 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (13)_crop_0_out1.jpg
# Processing 279 2559 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (2)_crop_0_out1.jpg
# Processing 280 2559 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (3)_crop_0_out1.jpg
# Processing 281 2559 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (4)_crop_0_out1.jpg
# Processing 282 2559 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (5)_crop_0_out1.jpg
# Processing 283 2559 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (6)_crop_0_out1.jpg
# Processing 284 2559 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (7)_crop_0_out1.jpg
# Processing 285 2559 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (8)_crop_0_out1.jpg
# Processing 286 2559 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559 (9)_crop_0_out1.jpg
# Processing 287 2559_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2559_crop_0_out1.jpg
# Processing 288 2689 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (2)_crop_0_out1.jpg
# Processing 289 2689 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (3)_crop_0_out1.jpg
# Processing 290 2689 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (4)_crop_0_out1.jpg
# Processing 291 2689 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (5)_crop_0_out1.jpg
# Processing 292 2689 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (6)_crop_0_out1.jpg
# Processing 293 2689 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689 (7)_crop_0_out1.jpg
# Processing 294 2689_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2689_crop_0_out1.jpg
# Processing 295 2799 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (1)_crop_0_out1.jpg
# Processing 296 2799 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (10)_crop_0_out1.jpg
# Processing 297 2799 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (11)_crop_0_out1.jpg
# Processing 298 2799 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (12)_crop_0_out1.jpg
# Processing 299 2799 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (13)_crop_0_out1.jpg
# Processing 300 2799 (14)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (14)_crop_0_out1.jpg
# Processing 301 2799 (15)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (15)_crop_0_out1.jpg
# Processing 302 2799 (16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (16)_crop_0_out1.jpg
# Processing 303 2799 (17)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (17)_crop_0_out1.jpg
# Processing 304 2799 (18)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (18)_crop_0_out1.jpg
# Processing 305 2799 (19)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (19)_crop_0_out1.jpg
# Processing 306 2799 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (2)_crop_0_out1.jpg
# Processing 307 2799 (20)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (20)_crop_0_out1.jpg
# Processing 308 2799 (21)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (21)_crop_0_out1.jpg
# Processing 309 2799 (22)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (22)_crop_0_out1.jpg
# Processing 310 2799 (23)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (23)_crop_0_out1.jpg
# Processing 311 2799 (24)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (24)_crop_0_out1.jpg
# Processing 312 2799 (25)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (25)_crop_0_out1.jpg
# Processing 313 2799 (26)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (26)_crop_0_out1.jpg
# Processing 314 2799 (27)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (27)_crop_0_out1.jpg
# Processing 315 2799 (28)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (28)_crop_0_out1.jpg
# Processing 316 2799 (29)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (29)_crop_0_out1.jpg
# Processing 317 2799 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (3)_crop_0_out1.jpg
# Processing 318 2799 (30)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (30)_crop_0_out1.jpg
# Processing 319 2799 (31)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (31)_crop_0_out1.jpg
# Processing 320 2799 (32)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (32)_crop_0_out1.jpg
# Processing 321 2799 (33)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (33)_crop_0_out1.jpg
# Processing 322 2799 (34)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (34)_crop_0_out1.jpg
# Processing 323 2799 (35)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (35)_crop_0_out1.jpg
# Processing 324 2799 (36)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (36)_crop_0_out1.jpg
# Processing 325 2799 (37)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (37)_crop_0_out1.jpg
# Processing 326 2799 (38)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (38)_crop_0_out1.jpg
# Processing 327 2799 (39)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (39)_crop_0_out1.jpg
# Processing 328 2799 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (4)_crop_0_out1.jpg
# Processing 329 2799 (40)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (40)_crop_0_out1.jpg
# Processing 330 2799 (41)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (41)_crop_0_out1.jpg
# Processing 331 2799 (42)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (42)_crop_0_out1.jpg
# Processing 332 2799 (43)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (43)_crop_0_out1.jpg
# Processing 333 2799 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (5)_crop_0_out1.jpg
# Processing 334 2799 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (6)_crop_0_out1.jpg
# Processing 335 2799 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (7)_crop_0_out1.jpg
# Processing 336 2799 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (8)_crop_0_out1.jpg
# Processing 337 2799 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799 (9)_crop_0_out1.jpg
# Processing 338 2799_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2799_crop_0_out1.jpg
# Processing 339 2821 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (10)_crop_0_out1.jpg
# Processing 340 2821 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (11)_crop_0_out1.jpg
# Processing 341 2821 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (12)_crop_0_out1.jpg
# Processing 342 2821 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (13)_crop_0_out1.jpg
# Processing 343 2821 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (2)_crop_0_out1.jpg
# Processing 344 2821 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (3)_crop_0_out1.jpg
# Processing 345 2821 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (4)_crop_0_out1.jpg
# Processing 346 2821 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (5)_crop_0_out1.jpg
# Processing 347 2821 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (6)_crop_0_out1.jpg
# Processing 348 2821 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (7)_crop_0_out1.jpg
# Processing 349 2821 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (8)_crop_0_out1.jpg
# Processing 350 2821 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821 (9)_crop_0_out1.jpg
# Processing 351 2821_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\2821_crop_0_out1.jpg
# Processing 352 3089 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3089 (2)_crop_0_out1.jpg
# Processing 353 3089_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3089_crop_0_out1.jpg
# Processing 354 3196_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3196_crop_0_out1.jpg
# Processing 355 3210 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3210 (10)_crop_0_out1.jpg
# Processing 356 3210 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3210 (11)_crop_0_out1.jpg
# Processing 357 3210 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3210 (12)_crop_0_out1.jpg
# Processing 358 3210 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\3210 (13)_crop_0_out1.jpg
# Processing 359 3210 (14)_crop_0
# ...
# Processing 1309 9105 (44)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (44)_crop_0_out1.jpg
# Processing 1310 9105 (45)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (45)_crop_0_out1.jpg
# Processing 1311 9105 (46)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (46)_crop_0_out1.jpg
# Processing 1312 9105 (47)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (47)_crop_0_out1.jpg
# Processing 1313 9105 (48)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (48)_crop_0_out1.jpg
# Processing 1314 9105 (49)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (49)_crop_0_out1.jpg
# Processing 1315 9105 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (5)_crop_0_out1.jpg
# Processing 1316 9105 (50)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (50)_crop_0_out1.jpg
# Processing 1317 9105 (51)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (51)_crop_0_out1.jpg
# Processing 1318 9105 (52)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (52)_crop_0_out1.jpg
# Processing 1319 9105 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (6)_crop_0_out1.jpg
# Processing 1320 9105 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (7)_crop_0_out1.jpg
# Processing 1321 9105 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (8)_crop_0_out1.jpg
# Processing 1322 9105 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105 (9)_crop_0_out1.jpg
# Processing 1323 9105_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9105_crop_0_out1.jpg
# Processing 1324 9135 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (1)_crop_0_out1.jpg
# Processing 1325 9135 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (10)_crop_0_out1.jpg
# Processing 1326 9135 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (11)_crop_0_out1.jpg
# Processing 1327 9135 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (2)_crop_0_out1.jpg
# Processing 1328 9135 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (3)_crop_0_out1.jpg
# Processing 1329 9135 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (4)_crop_0_out1.jpg
# Processing 1330 9135 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (5)_crop_0_out1.jpg
# Processing 1331 9135 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (6)_crop_0_out1.jpg
# Processing 1332 9135 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (7)_crop_0_out1.jpg
# Processing 1333 9135 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (8)_crop_0_out1.jpg
# Processing 1334 9135 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135 (9)_crop_0_out1.jpg
# Processing 1335 9135_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9135_crop_0_out1.jpg
# Processing 1336 9136 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9136 (2)_crop_0_out1.jpg
# Processing 1337 9136 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9136 (3)_crop_0_out1.jpg
# Processing 1338 9136 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9136 (4)_crop_0_out1.jpg
# Processing 1339 9136_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9136_crop_0_out1.jpg
# Processing 1340 9138 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (2)_crop_0_out1.jpg
# Processing 1341 9138 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (3)_crop_0_out1.jpg
# Processing 1342 9138 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (4)_crop_0_out1.jpg
# Processing 1343 9138 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (5)_crop_0_out1.jpg
# Processing 1344 9138 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (6)_crop_0_out1.jpg
# Processing 1345 9138 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138 (7)_crop_0_out1.jpg
# Processing 1346 9138_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9138_crop_0_out1.jpg
# Processing 1347 9570 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (1)_crop_0_out1.jpg
# Processing 1348 9570 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (10)_crop_0_out1.jpg
# Processing 1349 9570 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (11)_crop_0_out1.jpg
# Processing 1350 9570 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (12)_crop_0_out1.jpg
# Processing 1351 9570 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (13)_crop_0_out1.jpg
# Processing 1352 9570 (14)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (14)_crop_0_out1.jpg
# Processing 1353 9570 (15)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (15)_crop_0_out1.jpg
# Processing 1354 9570 (16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (16)_crop_0_out1.jpg
# Processing 1355 9570 (17)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (17)_crop_0_out1.jpg
# Processing 1356 9570 (18)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (18)_crop_0_out1.jpg
# Processing 1357 9570 (19)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (19)_crop_0_out1.jpg
# Processing 1358 9570 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (2)_crop_0_out1.jpg
# Processing 1359 9570 (20)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (20)_crop_0_out1.jpg
# Processing 1360 9570 (21)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (21)_crop_0_out1.jpg
# Processing 1361 9570 (22)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (22)_crop_0_out1.jpg
# Processing 1362 9570 (23)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (23)_crop_0_out1.jpg
# Processing 1363 9570 (24)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (24)_crop_0_out1.jpg
# Processing 1364 9570 (25)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (25)_crop_0_out1.jpg
# Processing 1365 9570 (26)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (26)_crop_0_out1.jpg
# Processing 1366 9570 (27)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (27)_crop_0_out1.jpg
# Processing 1367 9570 (28)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (28)_crop_0_out1.jpg
# Processing 1368 9570 (29)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (29)_crop_0_out1.jpg
# Processing 1369 9570 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (3)_crop_0_out1.jpg
# Processing 1370 9570 (30)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (30)_crop_0_out1.jpg
# Processing 1371 9570 (31)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (31)_crop_0_out1.jpg
# Processing 1372 9570 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (4)_crop_0_out1.jpg
# Processing 1373 9570 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (5)_crop_0_out1.jpg
# Processing 1374 9570 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (6)_crop_0_out1.jpg
# Processing 1375 9570 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (7)_crop_0_out1.jpg
# Processing 1376 9570 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (8)_crop_0_out1.jpg
# Processing 1377 9570 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570 (9)_crop_0_out1.jpg
# Processing 1378 9570_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9570_crop_0_out1.jpg
# Processing 1379 9695 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (1)_crop_0_out1.jpg
# Processing 1380 9695 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (10)_crop_0_out1.jpg
# Processing 1381 9695 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (11)_crop_0_out1.jpg
# Processing 1382 9695 (12)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (12)_crop_0_out1.jpg
# Processing 1383 9695 (13)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (13)_crop_0_out1.jpg
# Processing 1384 9695 (14)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (14)_crop_0_out1.jpg
# Processing 1385 9695 (15)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (15)_crop_0_out1.jpg
# Processing 1386 9695 (16)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (16)_crop_0_out1.jpg
# Processing 1387 9695 (17)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (17)_crop_0_out1.jpg
# Processing 1388 9695 (18)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (18)_crop_0_out1.jpg
# Processing 1389 9695 (19)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (19)_crop_0_out1.jpg
# Processing 1390 9695 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (2)_crop_0_out1.jpg
# Processing 1391 9695 (20)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (20)_crop_0_out1.jpg
# Processing 1392 9695 (21)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (21)_crop_0_out1.jpg
# Processing 1393 9695 (22)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (22)_crop_0_out1.jpg
# Processing 1394 9695 (23)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (23)_crop_0_out1.jpg
# Processing 1395 9695 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (3)_crop_0_out1.jpg
# Processing 1396 9695 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (4)_crop_0_out1.jpg
# Processing 1397 9695 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (5)_crop_0_out1.jpg
# Processing 1398 9695 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (6)_crop_0_out1.jpg
# Processing 1399 9695 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (7)_crop_0_out1.jpg
# Processing 1400 9695 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (8)_crop_0_out1.jpg
# Processing 1401 9695 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695 (9)_crop_0_out1.jpg
# Processing 1402 9695_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9695_crop_0_out1.jpg
# Processing 1403 9776 (1)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (1)_crop_0_out1.jpg
# Processing 1404 9776 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (2)_crop_0_out1.jpg
# Processing 1405 9776 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (3)_crop_0_out1.jpg
# Processing 1406 9776 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (4)_crop_0_out1.jpg
# Processing 1407 9776 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (5)_crop_0_out1.jpg
# Processing 1408 9776 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (6)_crop_0_out1.jpg
# Processing 1409 9776 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (7)_crop_0_out1.jpg
# Processing 1410 9776 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (8)_crop_0_out1.jpg
# Processing 1411 9776 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776 (9)_crop_0_out1.jpg
# Processing 1412 9776_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9776_crop_0_out1.jpg
# Processing 1413 9786 (10)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (10)_crop_0_out1.jpg
# Processing 1414 9786 (11)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (11)_crop_0_out1.jpg
# Processing 1415 9786 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (2)_crop_0_out1.jpg
# Processing 1416 9786 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (3)_crop_0_out1.jpg
# Processing 1417 9786 (4)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (4)_crop_0_out1.jpg
# Processing 1418 9786 (5)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (5)_crop_0_out1.jpg
# Processing 1419 9786 (6)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (6)_crop_0_out1.jpg
# Processing 1420 9786 (7)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (7)_crop_0_out1.jpg
# Processing 1421 9786 (8)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (8)_crop_0_out1.jpg
# Processing 1422 9786 (9)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786 (9)_crop_0_out1.jpg
# Processing 1423 9786_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9786_crop_0_out1.jpg
# Processing 1424 9816 (2)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9816 (2)_crop_0_out1.jpg
# Processing 1425 9816 (3)_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9816 (3)_crop_0_out1.jpg
# Processing 1426 9816_crop_0
# Saved: C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up\9816_crop_0_out1.jpg
# Processing 1427 up
# Error reading image C:\Devtools\project\data\img_labeling\dh\cropped_number_plate_gray\up, skipping...

# %%
import torch
import gc

# After your processing is done
gc.collect()
torch.cuda.empty_cache()
